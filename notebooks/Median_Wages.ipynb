# %% [markdown]
# # Median Wages
# results and checks in notebook for internal review

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../utils')
import wd_management
wd_management.set_wd_root()
# Out:
# called set_wd_root. current working directory is /Users/alexanderweinstein/Documents/Data_Products/db-equitable-development-tool/notebooks

# %%
from aggregate.PUMS.count_PUMS_economics import PUMSCountEconomics
from aggregate.PUMS.median_PUMS_economics import PUMSMedianEconomics
from aggregate.PUMS.economic_indicators import industry_mapper, occupation_mapper

# %%
count_aggregator = PUMSCountEconomics(limited_PUMA=False)
counts = count_aggregator.aggregated

# %%
median_aggregator = PUMSMedianEconomics(limited_PUMA=False)
medians = median_aggregator.aggregated
# Out:
# iterated to wage
# calculate median passed data with 153026 rows
# variable col is wage
# crosstab is occupation
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
# calculate median passed data with 34426 rows
# variable col is wage
# crosstab is occupation
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# ...
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.
#
# R[write to console]: Not all replicate weight designs give valid standard errors for quantiles.

# %%
medians
# Out:
#       occupation-cstmnt-wage-anh-median  occupation-cstmnt-wage-anh-median-CV  \
# PUMA
# 4008                            40000.0                              0.141501
# 4001                            20000.0                              0.702122
# 4005                           103000.0                              0.000000
# 4016                            38000.0                              0.124999
# 3702                            15000.0                              0.000000
# 3701                            27000.0                              0.535556
# 3706                            25000.0                              0.031200
# 3710                                NaN                                   NaN
# 4003                            17000.0                              0.172905
# 4011                                NaN                                   NaN
# 4017                            35000.0                              0.189169
# 3704                            31200.0                              0.272428
# 3707                                NaN                                   NaN
# 4018                            20800.0                              0.290544
# 4006                            32000.0                                   NaN
# 4002                            30000.0                              0.558462
# 4009                            39000.0                              0.345990
# 4004                             3000.0                              4.059249
# 4014                            20000.0                              0.165701
# 4007                            18500.0                              0.000000
# 3709                            40000.0                              0.234824
# 4013                            30000.0                              0.533098
# 3705                                NaN                                   NaN
# 4010                                NaN                                   NaN
# 4015                            20000.0                              0.833370
# 4012                            22000.0                              0.077503
# 3703                                NaN                                   NaN
# 3708                            35000.0                                   NaN
# 3805                           105000.0                              0.000000
# 4106                            31000.0                              0.194869
# 3802                            70000.0                                   NaN
# 4107                            30000.0                              0.325013
# 3807                            26000.0                              0.253846
# 3801                            58000.0                                   NaN
# 4102                            30000.0                              0.462763
# 3901                            30000.0                              0.997218
# 4114                            34000.0                              0.103260
# 4104                            35000.0                              0.146969
# 4111                            26000.0                              0.129529
# 3903                            34600.0                              0.384042
# 3810                            69000.0                              0.000000
# 3803                                NaN                                   NaN
# 4112                            40000.0                              0.261244
# 4101                            33800.0                              0.696522
# 4113                            38000.0                              0.106958
# 3806                           200000.0                                   NaN
# 4109                            40000.0                              0.198608
# 4103                            25000.0                              0.023643
# 4105                            40000.0                              0.120882
# 3809                            15600.0                              0.546846
# 3804                            40000.0                                   NaN
# 3808                                NaN                                   NaN
# 4110                            44000.0                              0.232687
# 3902                            16000.0                              2.309032
# 4108                            40000.0                              0.480852
#
#       occupation-cstmnt-wage-anh-median-MOE  \
# PUMA
# 4008                            7253.615824
# 4001                           17996.105438
# 4005                               0.000000
# 4016                            6087.328623
# 3702                               0.000000
# 3701                           18531.235638
# 3706                             999.610221
# 3710                                    NaN
# 4003                            3766.976898
# 4011                                    NaN
# 4017                            8485.061241
# 3704                           10892.856606
# 3707                                    NaN
# 4018                            7744.813842
# 4006                                    NaN
# 4002                           21470.932408
# 4009                           17292.756506
# 4004                           15606.409575
# 4014                            4247.096498
# 4007                               0.000000
# 3709                           12037.581520
# 4013                           20495.769839
# 3705                                    NaN
# 4010                                    NaN
# 4015                           21360.131448
# 4012                            2185.127629
# 3703                                    NaN
# 3708                                    NaN
# 3805                               0.000000
# 4106                            7741.780110
# 3802                                    NaN
# 4107                           12495.619016
# 3807                            8458.240333
# 3801                                    NaN
# 4102                           17791.627425
# 3901                           38339.602261
# 4114                            4499.318391
# 4104                            6592.209571
# 4111                            4315.951932
# 3903                           17029.071836
# 3810                               0.000000
# 3803                                    NaN
# 4112                           13391.907265
# 4101                           30170.867682
# 4113                            5208.742541
# 3806                                    NaN
# 4109                           10181.035951
# 4103                             757.498885
# 4105                            6196.639758
# 3809                           10932.663953
# 3804                                    NaN
# 3808                                    NaN
# 4110                           13120.795994
# 3902                           47346.306438
# 4108                           24649.450063
#
#       occupation-cstmnt-wage-bnh-median  occupation-cstmnt-wage-bnh-median-CV  \
# PUMA
# 4008                            55000.0                              0.120605
# 4001                            50000.0                              0.097980
# 4005                            14000.0                              0.797085
# 4016                            67000.0                              0.534964
# 3702                            40000.0                              0.091660
# 3701                            97000.0                              1.250237
# 3706                            50000.0                              0.154596
# 3710                            30000.0                              0.179997
# 4003                            46000.0                              0.160007
# 4011                            63000.0                              0.129814
# 4017                            40000.0                              0.000000
# 3704                            50000.0                              0.139485
# 3707                            35000.0                              0.255387
# 4018                           120000.0                                   NaN
# 4006                            40000.0                              0.235846
# 4002                            70000.0                              0.039768
# 4009                            50000.0                              0.037253
# 4004                            45000.0                              0.190435
# 4014                            65000.0                              0.072058
# 4007                            40000.0                              0.125925
# 3709                            60000.0                              0.330420
# 4013                            20000.0                              0.264575
# 3705                            40000.0                              0.103000
# 4010                            47000.0                              0.084723
# 4015                            45000.0                              0.088685
# 4012                            47000.0                              0.833869
# 3703                            36600.0                              0.304838
# 3708                            30000.0                              0.388730
# 3805                                NaN                                   NaN
# 4106                            80000.0                              0.260404
# 3802                            30000.0                              0.503994
# 4107                            38000.0                              0.099407
# 3807                            47000.0                                   NaN
# 3801                            90000.0                                   NaN
# 4102                            30000.0                              0.229672
# 3901                                NaN                                   NaN
# 4114                            48000.0                              0.143724
# 4104                            60000.0                              0.055551
# 4111                            60000.0                              0.088569
# 3903                            50000.0                              0.044821
# 3810                             5400.0                                   NaN
# 3803                            32000.0                              0.119723
# 4112                            50000.0                              0.080498
# 4101                            30000.0                              0.611735
# 4113                            50000.0                              0.239472
# 3806                            33000.0                              0.000000
# 4109                                NaN                                   NaN
# 4103                            60000.0                              0.182384
# 4105                            58000.0                              0.099699
# 3809                           110000.0                              0.086862
# 3804                            62000.0                              0.290233
# 3808                            70000.0                              0.000000
# 4110                            65000.0                              0.171962
# 3902                           100000.0                              0.000000
# 4108                            17000.0                              0.209134
#
#       occupation-cstmnt-wage-bnh-median-MOE  \
# PUMA
# 4008                            8500.851385
# 4001                            6278.294829
# 4005                           14301.081925
# 4016                           45934.090426
# 3702                            4698.700066
# 3701                          155417.600213
# 3706                            9906.153204
# 3710                            6920.271657
# 4003                            9432.635234
# 4011                           10480.896253
# 4017                               0.000000
# 3704                            8937.846024
# 3707                           11455.200122
# 4018                                    NaN
# 4006                           12089.963483
# 4002                            3567.544707
# 4009                            2387.051054
# 4004                           10982.343607
# 4014                            6002.465221
# 4007                            6455.159302
# 3709                           25406.981997
# 4013                            6781.333469
# 3705                            5279.988562
# 4010                            5103.101282
# 4015                            5114.462609
# 4012                           50226.358634
# 3703                           14298.346972
# 3708                           14945.318696
# 3805                                    NaN
# 4106                           26697.655966
# 3802                           19376.846714
# 4107                            4841.038775
# 3807                                    NaN
# 3801                                    NaN
# 4102                            8830.101861
# 3901                                    NaN
# 4114                            8841.098493
# 4104                            4271.504801
# 4111                            6810.334315
# 3903                            2872.048270
# 3810                                    NaN
# 3803                            4909.781103
# 4112                            5158.145551
# 4101                           23519.090057
# 4113                           15344.804384
# 3806                               0.000000
# 4109                                    NaN
# 4103                           14024.062757
# 4105                            7410.593398
# 3809                           12244.980431
# 3804                           23060.807350
# 3808                               0.000000
# 4110                           14324.599593
# 3902                               0.000000
# 4108                            4556.271788
#
#       occupation-cstmnt-wage-hsp-median  occupation-cstmnt-wage-hsp-median-CV  \
# PUMA
# 4008                            40000.0                              0.123236
# 4001                            45000.0                              0.120864
# 4005                            46300.0                              0.167243
# 4016                            25000.0                              0.249432
# 3702                            50000.0                              0.077614
# 3701                            20000.0                              0.375624
# 3706                            30000.0                              0.056667
# 3710                            29000.0                              0.089741
# 4003                            30000.0                              0.168603
# 4011                            40000.0                              0.314223
# 4017                            24000.0                              0.046573
# 3704                            45000.0                              0.118007
# 3707                            28000.0                              0.100964
# 4018                            30000.0                              0.137783
# 4006                            42000.0                              0.185780
# 4002                            35000.0                              0.049836
# 4009                            50000.0                              0.239163
# 4004                            36700.0                              0.199165
# 4014                            25000.0                              0.140006
# 4007                            30000.0                              0.257654
# 3709                            33000.0                              0.064253
# 4013                            30000.0                              0.184517
# 3705                            33000.0                              0.068507
# 4010                            37400.0                              0.213586
# 4015                            27000.0                              0.070926
# 4012                            26900.0                              0.096813
# 3703                            70000.0                              0.204221
# 3708                            30000.0                              0.101650
# 3805                            50000.0                              0.177305
# 4106                            42000.0                              0.230128
# 3802                            36000.0                              0.249223
# 4107                            30000.0                              0.047046
# 3807                            30000.0                              0.935967
# 3801                            30000.0                              0.116516
# 4102                            30000.0                              0.032024
# 3901                            55000.0                              0.266187
# 4114                            31200.0                              0.230645
# 4104                            61000.0                              0.345819
# 4111                            36000.0                              0.067329
# 3903                            35000.0                              0.160454
# 3810                           117000.0                              0.133289
# 3803                            35000.0                              0.144076
# 4112                            30000.0                              0.048503
# 4101                            40000.0                              0.122697
# 4113                            46700.0                              0.235015
# 3806                            30000.0                              0.000000
# 4109                            35000.0                              0.153570
# 4103                            36000.0                              0.082812
# 4105                            40000.0                              0.214341
# 3809                            35000.0                              0.348176
# 3804                            35000.0                              0.144510
# 3808                            20000.0                              0.000000
# 4110                            38900.0                              0.070403
# 3902                            35000.0                              0.198679
# 4108                            45000.0                              0.346088
#
#       occupation-cstmnt-wage-hsp-median-MOE  occupation-cstmnt-wage-median  \
# PUMA
# 4008                            6317.331067                        48000.0
# 4001                            6970.184926                        49000.0
# 4005                            9923.494518                        63000.0
# 4016                            7991.488808                        40000.0
# 3702                            4973.344819                        45000.0
# 3701                            9627.642809                        24000.0
# 3706                            2178.637661                        30000.0
# 3710                            3335.211789                        30000.0
# 4003                            6482.215896                        40000.0
# 4011                           16107.706360                        60000.0
# 4017                            1432.459959                        32000.0
# 3704                            6805.434007                        45000.0
# 3707                            3622.939703                        30000.0
# 4018                            5297.286071                        35000.0
# 4006                            9999.615592                        40000.0
# 4002                            2235.359428                        36400.0
# 4009                           15324.993815                        50000.0
# 4004                            9367.324503                        40000.0
# 4014                            4485.631862                        26900.0
# 4007                            9905.924718                        39500.0
# 3709                            2717.342660                        35000.0
# 4013                            7094.053550                        44000.0
# 3705                            2897.263291                        35000.0
# 4010                           10237.164739                        45500.0
# 4015                            2454.177522                        40000.0
# 4012                            3337.499287                        26900.0
# 3703                           18320.361227                        56000.0
# 3708                            3908.075687                        30000.0
# 3805                           11361.283505                        60000.0
# 4106                           12386.669907                        40000.0
# 3802                           11498.131782                        36000.0
# 4107                            1808.759198                        30000.0
# 3807                           35984.705869                        30000.0
# 3801                            4479.641454                        33000.0
# 4102                            1231.206939                        30000.0
# 3901                           18762.260690                        60000.0
# 4114                            9222.219505                        48000.0
# 4104                           27034.283952                        55000.0
# 4111                            3106.260985                        35100.0
# 3903                            7197.073103                        49600.0
# 3810                           19985.528560                        69000.0
# 3803                            6462.426292                        30000.0
# 4112                            1864.753862                        43800.0
# 4101                            6289.721881                        49100.0
# 4113                           14065.282404                        45000.0
# 3806                               0.000000                        31200.0
# 4109                            6888.265156                        42000.0
# 4103                            3820.602432                        35000.0
# 4105                           10987.572295                        50000.0
# 3809                           15617.171627                        30000.0
# 3804                            6481.911850                        40000.0
# 3808                               0.000000                        66000.0
# 4110                            3509.767095                        50000.0
# 3902                            8911.613244                        60000.0
# 4108                           19958.821039                        49000.0
#
#       ...  occupation-srvc-wage-hsp-median-MOE  occupation-srvc-wage-median  \
# PUMA  ...
# 4008  ...                          1897.983926                      27000.0
# 4001  ...                          2780.228578                      26900.0
# 4005  ...                          2976.677673                      30000.0
# 4016  ...                          5253.578950                      26500.0
# 3702  ...                          3885.426796                      25000.0
# 3701  ...                          1073.830097                      21500.0
# 3706  ...                          1332.963802                      20800.0
# 3710  ...                           377.337511                      20000.0
# 4003  ...                          1857.362968                      26100.0
# 4011  ...                          3463.212309                      28300.0
# 4017  ...                          3166.221888                      20600.0
# 3704  ...                          3180.462696                      25000.0
# 3707  ...                           563.144950                      20000.0
# 4018  ...                          4295.468551                      22400.0
# 4006  ...                          4278.394931                      25000.0
# 4002  ...                          1594.357155                      22000.0
# 4009  ...                          4151.910628                      29000.0
# 4004  ...                          3321.381087                      24700.0
# 4014  ...                          3178.428742                      20000.0
# 4007  ...                          1737.291339                      25000.0
# 3709  ...                          1572.288684                      21800.0
# 4013  ...                          5185.098680                      23000.0
# 3705  ...                          1260.733477                      21000.0
# 4010  ...                         11279.287910                      28000.0
# 4015  ...                          3108.231533                      24000.0
# 4012  ...                          1974.356424                      20000.0
# 3703  ...                          5867.123764                      26000.0
# 3708  ...                          1051.321512                      20000.0
# 3805  ...                          2468.234713                      30000.0
# 4106  ...                          2536.363445                      24000.0
# 3802  ...                          1706.675353                      21500.0
# 4107  ...                          2122.155654                      25000.0
# 3807  ...                          5274.911040                      27300.0
# 3801  ...                          1537.057361                      23400.0
# 4102  ...                           558.615377                      25000.0
# 3901  ...                         11683.308531                      41900.0
# 4114  ...                          3939.468459                      30000.0
# 4104  ...                          4060.066806                      25000.0
# 4111  ...                          1521.943656                      24400.0
# 3903  ...                          2466.693404                      26000.0
# 3810  ...                         28869.046927                      20000.0
# 3803  ...                          2639.179576                      24000.0
# 4112  ...                          1982.201848                      27300.0
# 4101  ...                          2801.104630                      27000.0
# 4113  ...                          3714.974623                      27400.0
# 3806  ...                          3355.848671                      29600.0
# 4109  ...                           495.307660                      28000.0
# 4103  ...                          2097.354184                      20000.0
# 4105  ...                          4493.240001                      30000.0
# 3809  ...                          4344.062848                      20000.0
# 3804  ...                          2630.140676                      23900.0
# 3808  ...                         21877.244183                      34000.0
# 4110  ...                          2873.356074                      29000.0
# 3902  ...                          5675.664036                      35000.0
# 4108  ...                          1397.287961                      33000.0
#
#       occupation-srvc-wage-median-CV  occupation-srvc-wage-median-MOE  \
# PUMA
# 4008                        0.070150                      2427.314149
# 4001                        0.062505                      2154.796149
# 4005                        0.058062                      2232.292143
# 4016                        0.050586                      1717.948435
# 3702                        0.054018                      1730.661133
# 3701                        0.062080                      1710.520317
# 3706                        0.054104                      1442.211778
# 3710                        0.013036                       334.126325
# 4003                        0.041826                      1399.002261
# 4011                        0.062768                      2276.468135
# 4017                        0.034612                       913.751658
# 3704                        0.028900                       925.909920
# 3707                        0.033233                       851.798073
# 4018                        0.071550                      2053.961269
# 4006                        0.051792                      1659.349483
# 4002                        0.052154                      1470.433831
# 4009                        0.042068                      1563.463366
# 4004                        0.050518                      1599.117558
# 4014                        0.053557                      1372.722849
# 4007                        0.013142                       421.051129
# 3709                        0.053326                      1489.800250
# 4013                        0.067538                      1990.730621
# 3705                        0.041256                      1110.300066
# 4010                        0.035610                      1277.825645
# 4015                        0.033850                      1041.137414
# 4012                        0.031701                       812.522895
# 3703                        0.065403                      2179.240661
# 3708                        0.027475                       704.205006
# 3805                        0.254567                      9787.209809
# 4106                        0.069959                      2151.745210
# 3802                        0.086878                      2393.792876
# 4107                        0.036187                      1159.392546
# 3807                        0.112044                      3920.007061
# 3801                        0.030157                       904.356898
# 4102                        0.000000                         0.000000
# 3901                        0.096194                      5165.304674
# 4114                        0.045673                      1755.979949
# 4104                        0.045882                      1470.014922
# 4111                        0.040437                      1264.456995
# 3903                        0.080965                      2697.772586
# 3810                        0.188078                      4820.640154
# 3803                        0.064731                      1990.947174
# 4112                        0.038229                      1337.484186
# 4101                        0.058125                      2011.250140
# 4113                        0.055431                      1946.429614
# 3806                        0.208126                      7895.020756
# 4109                        0.011152                       400.164348
# 4103                        0.040449                      1036.745712
# 4105                        0.019667                       756.115424
# 3809                        0.053327                      1366.817703
# 3804                        0.117908                      3611.428172
# 3808                        0.173050                      7540.270316
# 4110                        0.050921                      1892.489266
# 3902                        0.026722                      1198.606172
# 4108                        0.148695                      6288.481437
#
#       occupation-srvc-wage-onh-median  occupation-srvc-wage-onh-median-CV  \
# PUMA
# 4008                          16600.0                            0.086629
# 4001                          24000.0                            0.351391
# 4005                          38000.0                            0.277890
# 4016                          19000.0                            0.339804
# 3702                          19000.0                            0.291259
# 3701                          42000.0                            0.260918
# 3706                          20000.0                            0.239991
# 3710                          37000.0                            0.255036
# 4003                          22500.0                            0.160800
# 4011                          35000.0                            0.424396
# 4017                          20000.0                            0.182621
# 3704                          25000.0                            0.429855
# 3707                          20200.0                            0.772765
# 4018                          24900.0                            0.169195
# 4006                          43000.0                            0.278035
# 4002                          26000.0                            0.432604
# 4009                          24000.0                            0.325132
# 4004                          26000.0                            0.937789
# 4014                          16900.0                            0.279753
# 4007                          22000.0                            0.125932
# 3709                          20000.0                            0.193968
# 4013                          13700.0                            0.755625
# 3705                          26000.0                            0.245657
# 4010                          20000.0                            0.336505
# 4015                          22900.0                            0.161256
# 4012                          35000.0                            0.812898
# 3703                          14000.0                            0.571384
# 3708                           2400.0                            6.869498
# 3805                          20000.0                            0.000000
# 4106                          20000.0                            0.395504
# 3802                          14700.0                            0.933722
# 4107                          42000.0                            0.337705
# 3807                          23000.0                            0.106272
# 3801                          18000.0                            0.658685
# 4102                          12000.0                            3.423478
# 3901                         108000.0                                 NaN
# 4114                          29500.0                            1.053005
# 4104                         110000.0                            0.769962
# 4111                          22000.0                            0.119070
# 3903                          15600.0                            0.407898
# 3810                          20000.0                            0.347579
# 3803                          43000.0                            0.474060
# 4112                          30000.0                            0.037969
# 4101                          30000.0                            0.313333
# 4113                          24000.0                            0.087338
# 3806                          55000.0                            0.578545
# 4109                          20000.0                            0.298286
# 4103                          25000.0                            0.284596
# 4105                          26000.0                            0.147804
# 3809                          15000.0                            0.762797
# 3804                          17000.0                            0.889975
# 3808                           5600.0                            0.040711
# 4110                          29000.0                            0.642883
# 3902                          28000.0                            0.673311
# 4108                          12000.0                            0.259239
#
#       occupation-srvc-wage-onh-median-MOE  occupation-srvc-wage-wnh-median  \
# PUMA
# 4008                          1842.929524                          23000.0
# 4001                         10807.801979                          30500.0
# 4005                         13532.966084                          35000.0
# 4016                          8274.060561                          30000.0
# 3702                          7092.015932                          40000.0
# 3701                         14043.957545                          26000.0
# 3706                          6151.213060                          20800.0
# 3710                         12093.146957                          40000.0
# 4003                          4636.639351                          30000.0
# 4011                         19036.002338                          28000.0
# 4017                          4680.751963                          25000.0
# 3704                         13772.021742                          28000.0
# 3707                         20004.835217                          30000.0
# 4018                          5399.105413                          26100.0
# 4006                         15321.610899                          27000.0
# 4002                         14414.506886                          30000.0
# 4009                         10000.176058                          28000.0
# 4004                         31247.447800                          26000.0
# 4014                          6058.961122                          18200.0
# 4007                          3550.555612                          18800.0
# 3709                          4971.590134                          15700.0
# 4013                         13266.701640                          30000.0
# 3705                          8185.390840                          20000.0
# 4010                          8624.982472                          25000.0
# 4015                          4732.466451                          24000.0
# 4012                         36461.986053                          28800.0
# 3703                         10251.611523                          30000.0
# 3708                         21128.677579                          31000.0
# 3805                             0.000000                          35000.0
# 4106                         10137.176169                          30000.0
# 3802                         17590.204146                          24000.0
# 4107                         18177.008733                          45000.0
# 3807                          3132.436854                          45000.0
# 3801                         15194.508146                          30000.0
# 4102                         52648.368424                          38000.0
# 3901                                  NaN                          45000.0
# 4114                         39809.649150                          40000.0
# 4104                        108542.027235                          35000.0
# 4111                          3357.064321                          34300.0
# 3903                          8154.777558                          40000.0
# 3810                          8908.799982                          35000.0
# 3803                         26123.906073                          30000.0
# 4112                          1459.787931                          54000.0
# 4101                         12046.584716                          34000.0
# 4113                          2686.278132                          40000.0
# 3806                         40778.922486                          37000.0
# 4109                          7645.373496                          34700.0
# 4103                          9118.120059                          29200.0
# 4105                          4924.890283                          30000.0
# 3809                         14663.450276                          33300.0
# 3804                         19389.324611                          28000.0
# 3808                           292.168462                          36000.0
# 4110                         23892.737484                          30000.0
# 3902                         24160.710691                          38000.0
# 4108                          3986.737815                          37500.0
#
#       occupation-srvc-wage-wnh-median-CV  occupation-srvc-wage-wnh-median-MOE
# PUMA
# 4008                            0.115434                          3402.489238
# 4001                            0.077918                          3045.605004
# 4005                            0.105914                          4750.720469
# 4016                            0.030171                          1159.959040
# 3702                            0.082377                          4222.804780
# 3701                            0.120676                          4020.963769
# 3706                            0.181705                          4843.582562
# 3710                            0.512537                         26273.682468
# 4003                            0.119127                          4580.018588
# 4011                            0.083661                          3002.053348
# 4017                            0.042222                          1352.746580
# 3704                            0.120379                          4319.603532
# 3707                            0.105327                          4049.454537
# 4018                            0.121654                          4069.152000
# 4006                            0.105720                          3658.128278
# 4002                            0.042591                          1637.479914
# 4009                            0.146975                          5273.969105
# 4004                            0.175740                          5855.722225
# 4014                            0.114939                          2680.856091
# 4007                            0.302256                          7282.300483
# 3709                            0.509794                         10257.232728
# 4013                            0.198653                          7637.519828
# 3705                            0.452681                         11602.676631
# 4010                            0.726366                         23271.895802
# 4015                            0.042512                          1307.543769
# 4012                            0.094371                          3483.127725
# 3703                            0.123450                          4746.237080
# 3708                            0.135976                          5402.070488
# 3805                            0.062953                          2823.733551
# 4106                            0.118340                          4549.768647
# 3802                            0.182500                          5613.192200
# 4107                            0.147864                          8527.314979
# 3807                            0.158152                          9120.594150
# 3801                            0.134013                          5152.347339
# 4102                            0.069992                          3408.540208
# 3901                            0.085367                          4923.100606
# 4114                            0.070049                          3590.860835
# 4104                            0.167435                          7510.192190
# 4111                            0.101240                          4450.214337
# 3903                            0.168172                          8620.830304
# 3810                            0.226120                         10142.440289
# 3803                            0.059249                          2277.910593
# 4112                            0.303655                         21014.099895
# 4101                            0.082178                          3580.714186
# 4113                            0.349999                         17941.685016
# 3806                            0.115293                          5466.910318
# 4109                            0.114874                          5108.409862
# 4103                            0.114723                          4293.097323
# 4105                            0.203201                          7812.393817
# 3809                            0.118986                          5077.823637
# 3804                            0.256595                          9207.515453
# 3808                            0.155009                          7151.471128
# 4110                            0.096514                          3710.611892
# 3902                            0.084641                          4121.931861
# 4108                            0.227690                         10942.375061
#
# [55 rows x 90 columns]

# %% [markdown]
# Check for missing columns

# %%
for indicator, mapper in [('occupation',occupation_mapper),('industry',industry_mapper)]:
    for k, i in mapper.items():
        for race in ['wnh','bnh','anh','onh','hsp']:
            for measure in ['median','median-CV','median-MOE']:
                col_name = f'{indicator}-{i.lower()}-wage-{race}-{measure}'
                if col_name not in medians.columns:
                    print(f'missing {col_name} ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tg/01b257jj0dzg5fzzc3p3gj0w0000gq/T/ipykernel_4341/1533514982.py in <module>
# ----> 1 for indicator, mapper in [('occupation',occupation_mapper),('industry',industry_mapper)]:
#       2     for k, i in mapper.items():
#       3         for race in ['wnh','bnh','anh','onh','hsp']:
#       4             for measure in ['median','median-CV','median-MOE']:
#       5                 col_name = f'{indicator}-{i.lower()}-wage-{race}-{measure}'
#
# NameError: name 'occupation_mapper' is not defined

# %% [markdown]
# ## Check occupation
# This is first because fewer categories and thus easier

# %% [markdown]
# Categories for reference:
# ```python
# occupation_mapper = {
#     "Management, Business, Science, and Arts Occupations": "mbsa",
#     "Service Occupations": "srvc",
#     "Sales and Office Occupations": "slsoff",
#     "Natural Resources, Construction, and Maintenance Occupations": "cstmnt",
#     "Production, Transportation, and Material Moving Occupations": "prdtrn",
# }
# ```

# %% [markdown]
# We have 5 occupations, 5 races, and 3 measures per data point (median, CV, MOE).
# 3\*5 non-crosstabbed occupatons + 5\*5\*3 crosstabbed occupations should come out to 90 occupation columns

# %%
len([c for c in medians.columns if 'occupation' in c]) == 5*3 +  5*5*3
# Out:
# True

# %% [markdown]
# First check that industries typically associated with higher wages do indeed have higher wages

# %%
(medians['occupation-mbsa-wage-median'] - medians['occupation-srvc-wage-median'])
# Out:
# PUMA
# 4001    47100.0
# 3701    47500.0
# 3801    28600.0
# 3901    24100.0
# 4101    38000.0
# dtype: float64

# %% [markdown]
# Next look at an occupation-race crosstab with no workers. Does it have NaN median?

# %%
display(counts['occupation-cstmnt-bnh-count'])
display(medians['occupation-cstmnt-wage-bnh-median'])
# Out:
# PUMA
# 4001    216.0
# 3701     98.0
# 3801     69.0
# 3901      0.0
# 4101    207.0
# Name: occupation-cstmnt-bnh-count, dtype: float64
# PUMA
# 4001    50000.0
# 3701    97000.0
# 3801    90000.0
# 3901        NaN
# 4101    30000.0
# Name: occupation-cstmnt-wage-bnh-median, dtype: float64

# %% [markdown]
# Yes!

# %% [markdown]
# Do PUMA-occupation-races with fewer people generally have higher variance on the median?

# %% [markdown]
# First look at category with lots of people

# %%
display(counts['occupation-slsoff-wnh-count'])
display(medians['occupation-slsoff-wage-wnh-median'])
display(medians['occupation-slsoff-wage-wnh-median-CV'])
# Out:
# PUMA
# 4001    10885.0
# 3701     2127.0
# 3801     3562.0
# 3901    13381.0
# 4101     8981.0
# Name: occupation-slsoff-wnh-count, dtype: float64
# PUMA
# 4001    42000.0
# 3701    50000.0
# 3801    40000.0
# 3901    40000.0
# 4101    50000.0
# Name: occupation-slsoff-wage-wnh-median, dtype: float64
# PUMA
# 4001    0.093358
# 3701    0.109229
# 3801    0.054577
# 3901    0.076754
# 4101    0.008888
# Name: occupation-slsoff-wage-wnh-median-CV, dtype: float64

# %% [markdown]
# Then category with fewer

# %%
display(counts['occupation-prdtrn-onh-count'])
display(medians['occupation-prdtrn-wage-onh-median'])
display(medians['occupation-prdtrn-wage-onh-median-CV'])
# Out:
# PUMA
# 4001     13.0
# 3701     93.0
# 3801     77.0
# 3901    112.0
# 4101    206.0
# Name: occupation-prdtrn-onh-count, dtype: float64
# PUMA
# 4001     13000.0
# 3701     10000.0
# 3801    110000.0
# 3901     50000.0
# 4101     20000.0
# Name: occupation-prdtrn-wage-onh-median, dtype: float64
# PUMA
# 4001         NaN
# 3701    0.000000
# 3801    0.310882
# 3901    0.071414
# 4101    0.715804
# Name: occupation-prdtrn-wage-onh-median-CV, dtype: float64

# %% [markdown]
# Why do we get NaN for CV here?

# %%
PUMS = median_aggregator.PUMS

# %%
PUMS[(PUMS['PUMA']=='4001') & (PUMS['race']=='onh')&(PUMS['occupation']=='occupation-prdtrn')& (PUMS['WAGP']>0)]
# Out:
#                 PWGTP              RAC1P                         HISP  \
# person_id
# 2018HU02529112     13  Two or More Races  Not Spanish/Hispanic/Latino
#
#                NATIVITY                          LANX        ENG  AGEP  HINCP  \
# person_id
# 2018HU02529112   Native  Yes, speaks another language  Very well    25  58000
#
#                                        ESR   WAGP  ... PWGTP75 PWGTP76  \
# person_id                                          ...
# 2018HU02529112  Civilian employed, at work  13000  ...      18       3
#
#                PWGTP77 PWGTP78 PWGTP79  PWGTP80         industry  \
# person_id
# 2018HU02529112       5      13      14       23  industry-mnfctr
#
#                        occupation  race   wage
# person_id
# 2018HU02529112  occupation-prdtrn   onh  13000
#
# [1 rows x 99 columns]

# %% [markdown]
# I think our estimate of 13 workers comes from this one person with weight 13. I guess it can't get a measure of variance from one person. Is this worth asking population about?

# %% [markdown]
# ## Check industry
# Similar checks

# %%
industry_mapper = {
    "Agriculture, Forestry, Fishing and Hunting, and Mining": "AgFFHM",
    "Construction": "Cnstn",
    "Manufacturing": "MNfctr",
    "Wholesale Trade": "Whlsl",
    "Retail Trade": "Rtl",
    "Transportation and Warehousing, and Utilities": "TrWHUt",
    "Information": "Info",
    "Finance and Insurance,  and Real Estate and Rental and Leasing": "FIRE",
    "Professional, Scientific, and Management, and  Administrative and Waste Management Services": "PrfSMg",
    "Educational Services, and Health Care and Social Assistance": "EdHlth",
    "Arts, Entertainment, and Recreation, and  Accommodation and Food Services": "ArtEn",
    "Other Services (except Public Administration)": "Oth",
    "Public Administration": "PbAdm",
}
len(industry_mapper.keys())
# Out:
# 13

# %% [markdown]
# 13 industries, same check for column count as above
# 13\*3 columns for not crosstabbed by race
# 13\*5\*3 for crosstabbed by race

# %%
(13*3 + 13*5*3) - medians[[c for c in medians.columns if 'industry' in c]].shape[1]
# Out:
# 11

# %% [markdown]
# Off by eleven. Assume it's a race crosstab with zero people in it

# %%
counts.loc[:,counts.sum() == 0].columns
# Out:
# Index(['industry-agffhm-anh-fraction', 'industry-agffhm-anh-fraction-CV',
#        'industry-agffhm-anh-fraction-MOE', 'industry-agffhm-bnh-fraction',
#        'industry-agffhm-bnh-fraction-CV', 'industry-agffhm-bnh-fraction-MOE',
#        'industry-agffhm-onh-fraction', 'industry-agffhm-onh-fraction-CV',
#        'industry-agffhm-onh-fraction-MOE'],
#       dtype='object')

# %% [markdown]
# Check that these are indeed missing columns

# %%
'industry-agffhm-wage-anh-median' in medians.columns
# Out:
# False

# %%
'industry-agffhm-wage-bnh-median' in medians.columns
# Out:
# False

# %%
'industry-agffhm-wage-onh-median' in medians.columns
# Out:
# False

# %% [markdown]
# Just to be sure, hipanics and whites are present

# %%
'industry-agffhm-wage-hsp-median' in medians.columns
# Out:
# True

# %%
'industry-agffhm-wage-wnh-median' in medians.columns
# Out:
# True

# %% [markdown]
# Ok that accounts for nine of eleven missing columns. I assume we want these populated with NA?

# %% [markdown]
# Find missing industry columns the hard way

# %% [markdown]
# Missing variance measure for hispanics?

# %%
medians['industry-agffhm-wage-hsp-median']
# Out:
# PUMA
# 4001        NaN
# 3701    32000.0
# 3801    40000.0
# 3901        NaN
# 4101    27000.0
# Name: industry-agffhm-wage-hsp-median, dtype: float64

# %%
counts['industry-agffhm-hsp-count']
# Out:
# PUMA
# 4001     0.0
# 3701    29.0
# 3801    15.0
# 3901     0.0
# 4101    28.0
# Name: industry-agffhm-hsp-count, dtype: float64

# %%
PUMS[(PUMS['industry'] == 'industry-agffhm') & (PUMS['race']=='hsp')& (PUMS['WAGP']>0)]
# Out:
#                 PWGTP                            RAC1P          HISP NATIVITY  \
# person_id
# 20160002730311     29                Two or More Races  Puerto Rican   Native
# 20170001059951     28                      White alone  Puerto Rican   Native
# 2018HU00460482     15  Black or African American alone     Dominican   Native
#
#                                         LANX  \
# person_id
# 20160002730311  Yes, speaks another language
# 20170001059951  Yes, speaks another language
# 2018HU00460482       No, speaks only English
#
#                                                             ENG  AGEP   HINCP  \
# person_id
# 20160002730311                                        Very well    37  179000
# 20170001059951                                        Very well    23   27000
# 2018HU00460482  N/A (less than 5 years old/speaks only English)    22   82000
#
#                                        ESR   WAGP  ... PWGTP75 PWGTP76  \
# person_id                                          ...
# 20160002730311  Civilian employed, at work  32000  ...      27      35
# 20170001059951  Civilian employed, at work  27000  ...       8      30
# 2018HU00460482  Civilian employed, at work  40000  ...      16      31
#
#                PWGTP77 PWGTP78 PWGTP79  PWGTP80         industry  \
# person_id
# 20160002730311      27      52      30       25  industry-agffhm
# 20170001059951      44       8       9       48  industry-agffhm
# 2018HU00460482      15      13      14       17  industry-agffhm
#
#                        occupation  race   wage
# person_id
# 20160002730311  occupation-cstmnt   hsp  32000
# 20170001059951  occupation-cstmnt   hsp  27000
# 2018HU00460482  occupation-cstmnt   hsp  40000
#
# [3 rows x 99 columns]

# %% [markdown]
# Ok that adds up. If it can't get variance measure it simply doesn't include them instead of adding columns of NaN like I think we want

# %% [markdown]
# Check that if 0 workers in category then median wage is NA. We already saw this above but let's do fresh example to get away from that agriculture category that is giving us problems

# %%
display(counts['industry-cnstn-anh-count'])
display(medians['industry-cnstn-wage-anh-median'])
# Out:
# PUMA
# 4001    271.0
# 3701     19.0
# 3801      0.0
# 3901    253.0
# 4101    343.0
# Name: industry-cnstn-anh-count, dtype: float64
# PUMA
# 4001    52000.0
# 3701        NaN
# 3801        NaN
# 3901    30000.0
# 4101    38000.0
# Name: industry-cnstn-wage-anh-median, dtype: float64

# %% [markdown]
# Ok but why is the 3701 median also NA?

# %%
PUMS[(PUMS['industry']=='industry-cnstn')& (PUMS['race']=='anh')&(PUMS['PUMA']=='3701')]
# Out:
#                 PWGTP        RAC1P                         HISP      NATIVITY  \
# person_id
# 2018HU03773612     19  Asian alone  Not Spanish/Hispanic/Latino  Foreign born
# 2019HU03161291     21  Asian alone  Not Spanish/Hispanic/Latino  Foreign born
#
#                                         LANX        ENG  AGEP  HINCP  \
# person_id
# 2018HU03773612  Yes, speaks another language  Very well    36   2900
# 2019HU03161291  Yes, speaks another language   Not well    65  75000
#
#                                        ESR   WAGP  ... PWGTP75 PWGTP76  \
# person_id                                          ...
# 2018HU03773612  Civilian employed, at work      0  ...      15      12
# 2019HU03161291          Not in labor force  34000  ...       5      28
#
#                PWGTP77 PWGTP78 PWGTP79  PWGTP80        industry  \
# person_id
# 2018HU03773612      33       6       6       27  industry-cnstn
# 2019HU03161291      24       7      18        9  industry-cnstn
#
#                        occupation  race   wage
# person_id
# 2018HU03773612  occupation-cstmnt   anh      0
# 2019HU03161291  occupation-cstmnt   anh  34000
#
# [2 rows x 99 columns]

# %% [markdown]
# Ok great. Second person isn't in our universe at all for economics as they are not in labor force.
# First is in labor force and is in universe for counts but isn't in universe for wage medians as thier wage is 0.
#
# I read the "civilian employed population 16-64 **with earnings**; no percent calculated" in the denominator tab of the median wages in the data matrix as wages over 0. Maybe this was incorrect and this person should be counted and median wages for this data point will be zero. We should discuss

# %% [markdown]
# This example is cleaner

# %%
display(counts['industry-whlsl-bnh-count'])
display(medians['industry-whlsl-wage-bnh-median'])
# Out:
# PUMA
# 4001     0.0
# 3701     0.0
# 3801    13.0
# 3901     0.0
# 4101    52.0
# Name: industry-whlsl-bnh-count, dtype: float64
# PUMA
# 4001        NaN
# 3701        NaN
# 3801    80000.0
# 3901        NaN
# 4101    36700.0
# Name: industry-whlsl-wage-bnh-median, dtype: float64

# %% [markdown]
# Ok great. Think I know which improvements to make next: fill missing columns in two situations
# 1. There are no people in category
# 2. There is no variance because no category has more than one person
#
# Then I think I will be ready to open a pull request
