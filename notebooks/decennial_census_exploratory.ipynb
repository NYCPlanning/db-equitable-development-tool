# %%
### Exploratory notebook looking into the xlsx files Erica, DCP Population sent over

# %load_ext autoreload 
# %autoreload 2

# %%
import pandas as pd 
import os

# %%
#import sys 
#sys.path.append('../utils')
#import wd_management 
#wd_management.set_wd_root()

# %%
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in '/Users/max/Documents/dcp-projects/db-equitable-development-tool/notebooks': ['Median_Wages.ipynb', 'Rpy2_Fractions_Exploratory.ipynb', 'household_income_bands_checks.ipynb', 'demographics-economic-security-checks.ipynb', 'Area_within_Historic_District_Exploratory.ipynb', 'Housing-NY-Test.ipynb', 'Occupation_Variable_2012_PUMS.ipynb', 'decennial_census.ipynb', 'LEP_Custom_Denom.ipynb', '2012_5YearEstimates_PUMA_Column.ipynb', 'Housing-NY-Exploratory.ipynb']

# %%
df2000 = pd.read_excel("../resources/decennial_census_data/EDDT_Census2000PUMS.xlsx",
skiprows=1)

# %%
 df2000 = df2000.replace(
        {"GeoID": {
            "Bronx": "BX",
            "Brooklyn": "BK",
            "Manhattan": "MN",
            "Queens": "QN",
            "Staten Island": "SI",
            "NYC": "citywide",
        }
        }
    )

# %%
df2000.head(10)
# Out:
#       GeoID  Pop_00E  Pop_00M  Pop_00C  Pop_00P  Pop_00Z  PU16_00E  PU16_00M  \
# 0  citywide  8004759    14850      0.1      100      NaN   1719478     10831
# 1        BX  1335474     7564      0.3      100      NaN    355527      4761
# 2        BK  2452377     9352      0.2      100      NaN    580175      6204
# 3        MN  1549982     8016      0.3      100      NaN    232387      4143
# 4        QN  2217765     9079      0.2      100      NaN    450338      5584
# 5        SI   449161     4669      0.6      100      NaN    101051      2609
# 6      3701   106386     2323      1.3      100      NaN     22622      1244
# 7      3702   139419     2654      1.2      100      NaN     34020      1495
# 8      3703   111738     2380      1.3      100      NaN     22050      1240
# 9      3704   121704     2482      1.2      100      NaN     25024      1314
#
#    PU16_00C  PU16_00P  ...  Pop_H00E.1  Pop_H00M.1  Pop_H00C.1  Pop_H00P.1  \
# 0       0.4      21.5  ...     2150965       19785         0.6         100
# 1       0.8      26.6  ...      647474        9111         0.9         100
# 2       0.7      23.7  ...      479647        9799         1.2         100
# 3       1.1      15.0  ...      427171        8775         1.2         100
# 4       0.8      20.3  ...      544667       10112         1.1         100
# 5       1.6      22.5  ...       52006        3383         4.0         100
# 6       3.3      21.3  ...       40432        2498         3.8         100
# 7       2.7      24.4  ...       24744        2250         5.5         100
# 8       3.4      19.7  ...       27410        2269         5.0         100
# 9       3.2      20.6  ...       40361        2591         3.9         100
#
#    Pop_H00Z.1  FB_H00E  FB_H00M  FB_H00C  FB_H00P  FB_H00Z
# 0         NaN   886485     9550      0.7     41.2      0.2
# 1         NaN   201382     4448      1.3     31.1      0.5
# 2         NaN   172137     4303      1.5     35.9      0.5
# 3         NaN   192923     4420      1.4     45.2      0.5
# 4         NaN   307299     5534      1.1     56.4      1.5
# 5         NaN    12744     1197      5.7     24.5      1.7
# 6         NaN    15382     1234      4.9     38.0      1.9
# 7         NaN     4095      678     10.1     16.5      2.3
# 8         NaN     3013      582     11.7     11.0      1.9
# 9         NaN     9939     1028      6.3     24.6      2.0
#
# [10 rows x 426 columns]

# %%
df2000.dtypes
# Out:
# GeoID       object
# Pop_00E      int64
# Pop_00M      int64
# Pop_00C    float64
# Pop_00P      int64
#             ...
# FB_H00E      int64
# FB_H00M      int64
# FB_H00C    float64
# FB_H00P    float64
# FB_H00Z    float64
# Length: 426, dtype: object

# %%
df2000.set_index("GeoID", inplace = True)

# %%
df_citywide = df2000.loc["citywide"]

# %%
df_borough = df2000.loc[["BX", "BK", "MN", "QN", "SI"]]

# %%
df_puma = df2000.loc[3701:4114]

# %%
df_puma.head()
# Out:
#        Pop_00E  Pop_00M  Pop_00C  Pop_00P  Pop_00Z  PU16_00E  PU16_00M  \
# GeoID
# 3701    106386     2323      1.3      100      NaN     22622      1244
# 3702    139419     2654      1.2      100      NaN     34020      1495
# 3703    111738     2380      1.3      100      NaN     22050      1240
# 3704    121704     2482      1.2      100      NaN     25024      1314
# 3705    140777     2667      1.2      100      NaN     42829      1609
#
#        PU16_00C  PU16_00P  PU16_00Z  ...  Pop_H00E.1  Pop_H00M.1  Pop_H00C.1  \
# GeoID                                ...
# 3701        3.3      21.3       1.1  ...       40432        2498         3.8
# 3702        2.7      24.4       1.0  ...       24744        2250         5.5
# 3703        3.4      19.7       1.0  ...       27410        2269         5.0
# 3704        3.2      20.6       1.0  ...       40361        2591         3.9
# 3705        2.3      30.4       1.0  ...       81114        2925         2.2
#
#        Pop_H00P.1  Pop_H00Z.1  FB_H00E  FB_H00M  FB_H00C  FB_H00P  FB_H00Z
# GeoID
# 3701          100         NaN    15382     1234      4.9     38.0      1.9
# 3702          100         NaN     4095      678     10.1     16.5      2.3
# 3703          100         NaN     3013      582     11.7     11.0      1.9
# 3704          100         NaN     9939     1028      6.3     24.6      2.0
# 3705          100         NaN    21829     1461      4.1     26.9      1.5
#
# [5 rows x 425 columns]

# %%
print("Shape of new dataframes - df_citwide{} , df_borough{}, df_puma{}".format(df_citywide.shape, df_borough.shape, df_puma.shape))
# Out:
# Shape of new dataframes - df_citwide(425,) , df_borough(5, 425), df_puma(55, 425)

# %%
df_puma.head()
# Out:
#        Pop_00E  Pop_00M  Pop_00C  Pop_00P  Pop_00Z  PU16_00E  PU16_00M  \
# GeoID
# 3701    106386     2323      1.3      100      NaN     22622      1244
# 3702    139419     2654      1.2      100      NaN     34020      1495
# 3703    111738     2380      1.3      100      NaN     22050      1240
# 3704    121704     2482      1.2      100      NaN     25024      1314
# 3705    140777     2667      1.2      100      NaN     42829      1609
#
#        PU16_00C  PU16_00P  PU16_00Z  ...  Pop_H00E.1  Pop_H00M.1  Pop_H00C.1  \
# GeoID                                ...
# 3701        3.3      21.3       1.1  ...       40432        2498         3.8
# 3702        2.7      24.4       1.0  ...       24744        2250         5.5
# 3703        3.4      19.7       1.0  ...       27410        2269         5.0
# 3704        3.2      20.6       1.0  ...       40361        2591         3.9
# 3705        2.3      30.4       1.0  ...       81114        2925         2.2
#
#        Pop_H00P.1  Pop_H00Z.1  FB_H00E  FB_H00M  FB_H00C  FB_H00P  FB_H00Z
# GeoID
# 3701          100         NaN    15382     1234      4.9     38.0      1.9
# 3702          100         NaN     4095      678     10.1     16.5      2.3
# 3703          100         NaN     3013      582     11.7     11.0      1.9
# 3704          100         NaN     9939     1028      6.3     24.6      2.0
# 3705          100         NaN    21829     1461      4.1     26.9      1.5
#
# [5 rows x 425 columns]

# %%
df_puma_test = df_puma.drop(df_puma.filter(regex= "Occ|OOcc|ROcc|Z").columns, axis = 1)

# %%
test = df_puma_test.drop(df_puma_test.filter(regex="Z$|E.1$|M.1$|C.1$|P.1$|Z.1$").columns, axis=1)

# %%
test.head()
# Out:
#        Pop_00E  Pop_00M  Pop_00C  Pop_00P  PU16_00E  PU16_00M  PU16_00C  \
# GeoID
# 3701    106386     2323      1.3      100     22622      1244       3.3
# 3702    139419     2654      1.2      100     34020      1495       2.7
# 3703    111738     2380      1.3      100     22050      1240       3.4
# 3704    121704     2482      1.2      100     25024      1314       3.2
# 3705    140777     2667      1.2      100     42829      1609       2.3
#
#        PU16_00P  P16t64_00E  P16t64_00M  ...  FB_B00C  FB_B00P  FB_A00E  \
# GeoID                                    ...
# 3701       21.3       66267        1474  ...     12.1     20.0     3636
# 3702       24.4       89141        1671  ...      2.8     42.2     1535
# 3703       19.7       69388        1512  ...      9.6     16.5     1182
# 3704       20.6       78047        1560  ...      7.2     32.3     6051
# 3705       30.4       87568        1696  ...      8.3     12.2      878
#
#        FB_A00M  FB_A00C  FB_A00P  FB_H00E  FB_H00M  FB_H00C  FB_H00P
# GeoID
# 3701       637     10.7     77.9    15382     1234      4.9     38.0
# 3702       419     16.6     70.7     4095      678     10.1     16.5
# 3703       368     18.9     75.7     3013      582     11.7     11.0
# 3704       816      8.2     76.8     9939     1028      6.3     24.6
# 3705       318     22.0     88.7    21829     1461      4.1     26.9
#
# [5 rows x 260 columns]

# %%
test.columns = test.columns.str.replace("_", "-")

# %%
test.tail()
# Out:
#        Pop-00E  Pop-00M  Pop-00C  Pop-00P  PU16-00E  PU16-00M  PU16-00C  \
# GeoID
# 4110    167870     2907      1.1      100     33754      1531       2.8
# 4111    140173     2661      1.2      100     32611      1475       2.7
# 4112    218003     3302      0.9      100     53177      1869       2.1
# 4113    129660     2561      1.2      100     28519      1390       3.0
# 4114    103729     2294      1.3      100     25898      1299       3.1
#
#        PU16-00P  P16t64-00E  P16t64-00M  ...  FB-B00C  FB-B00P  FB-A00E  \
# GeoID                                    ...
# 4110       20.1      110941        1808  ...     27.8     29.8     7881
# 4111       23.3       94262        1638  ...      9.6     39.7    18100
# 4112       24.4      140582        2083  ...      3.0     24.8     7794
# 4113       22.0       85580        1590  ...      7.1     37.9    14062
# 4114       25.0       62688        1468  ...      6.4     22.6     1286
#
#        FB-A00M  FB-A00C  FB-A00P  FB-H00E  FB-H00M  FB-H00C  FB-H00P
# GeoID
# 4110       932      7.2     76.8    18429     1378      4.5     39.8
# 4111      1350      4.5     77.7    21381     1448      4.1     45.1
# 4112       932      7.3     80.8    16079     1313      5.0     55.8
# 4113      1204      5.2     76.7     8982      983      6.7     36.9
# 4114       383     18.1     77.5     6886      862      7.6     40.3
#
# [5 rows x 260 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0w/10m3bzb54hz5ns4dbxqj490c0000gq/T/ipykernel_63511/2125688056.py in <module>
# ----> 1 geo_rename_test.head()
#
# NameError: name 'geo_rename_test' is not defined

# %%
# Out:
#        Pop_00E  Pop_00M  Pop_00C  Pop_00P  Pop_00Z  PU16_00E  PU16_00M  \
# GeoID
# 3701    106386     2323      1.3      100      NaN     22622      1244
# 3702    139419     2654      1.2      100      NaN     34020      1495
# 3703    111738     2380      1.3      100      NaN     22050      1240
# 3704    121704     2482      1.2      100      NaN     25024      1314
# 3705    140777     2667      1.2      100      NaN     42829      1609
#
#        PU16_00C  PU16_00P  PU16_00Z  ...  Pop_H00E.1  Pop_H00M.1  Pop_H00C.1  \
# GeoID                                ...
# 3701        3.3      21.3       1.1  ...       40432        2498         3.8
# 3702        2.7      24.4       1.0  ...       24744        2250         5.5
# 3703        3.4      19.7       1.0  ...       27410        2269         5.0
# 3704        3.2      20.6       1.0  ...       40361        2591         3.9
# 3705        2.3      30.4       1.0  ...       81114        2925         2.2
#
#        Pop_H00P.1  Pop_H00Z.1  FB_H00E  FB_H00M  FB_H00C  FB_H00P  FB_H00Z
# GeoID
# 3701          100         NaN    15382     1234      4.9     38.0      1.9
# 3702          100         NaN     4095      678     10.1     16.5      2.3
# 3703          100         NaN     3013      582     11.7     11.0      1.9
# 3704          100         NaN     9939     1028      6.3     24.6      2.0
# 3705          100         NaN    21829     1461      4.1     26.9      1.5
#
# [5 rows x 425 columns]

# %%
# Out:
#     GeoID  Pop_00E  Pop_00M  Pop_00C  Pop_00P  Pop_00Z  PU16_00E  PU16_00M  \
# 0    3701   106386     2323      1.3      100      NaN     22622      1244
# 1    3702   139419     2654      1.2      100      NaN     34020      1495
# 2    3703   111738     2380      1.3      100      NaN     22050      1240
# 3    3704   121704     2482      1.2      100      NaN     25024      1314
# 4    3705   140777     2667      1.2      100      NaN     42829      1609
# 5    3706   131430     2578      1.2      100      NaN     37648      1528
# 6    3707   136018     2622      1.2      100      NaN     43571      1604
# 7    3708   130582     2570      1.2      100      NaN     40374      1557
# 8    3709   175216     2968      1.0      100      NaN     46724      1725
# 9    3710   142204     2680      1.1      100      NaN     40665      1588
# 10   3801   224189     3347      0.9      100      NaN     50769      1847
# 11   3802   125179     2517      1.2      100      NaN     23882      1296
# 12   3803   110838     2371      1.3      100      NaN     27289      1337
# 13   3804   117733     2442      1.3      100      NaN     28840      1376
# 14   3805   216825     3293      0.9      100      NaN     24028      1363
# 15   3806   194640     3125      1.0      100      NaN     22726      1321
# 16   3807   123136     2497      1.2      100      NaN      9403       869
# 17   3808   144479     2701      1.1      100      NaN     10799       932
# 18   3809   167512     2904      1.1      100      NaN     23980      1336
# 19   3810   125451     2520      1.2      100      NaN     10671       921
# 20   3901   155559     2800      1.1      100      NaN     33993      1519
# 21   3902   131283     2577      1.2      100      NaN     27603      1376
# 22   3903   162319     2859      1.1      100      NaN     39455      1611
# 23   4001   142534     2683      1.1      100      NaN     36539      1537
# 24   4002   116415     2429      1.3      100      NaN     34262      1449
# 25   4003   121057     2476      1.2      100      NaN     34738      1467
# 26   4004   113068     2394      1.3      100      NaN     18648      1163
# 27   4005   108376     2344      1.3      100      NaN     18755      1161
# 28   4006   120170     2467      1.2      100      NaN     29126      1385
# 29   4007   114262     2406      1.3      100      NaN     37423      1479
# 30   4008   143427     2691      1.1      100      NaN     40527      1589
# 31   4009   190396     3091      1.0      100      NaN     44462      1721
# 32   4010   146623     2720      1.1      100      NaN     35150      1524
# 33   4011   114012     2404      1.3      100      NaN     27111      1340
# 34   4012   136334     2625      1.2      100      NaN     31717      1454
# 35   4013   122506     2490      1.2      100      NaN     20681      1222
# 36   4014   160633     2845      1.1      100      NaN     46878      1698
# 37   4015   163638     2871      1.1      100      NaN     41284      1638
# 38   4016   150967     2760      1.1      100      NaN     29162      1430
# 39   4017   171385     2936      1.0      100      NaN     30713      1480
# 40   4018   116574     2430      1.3      100      NaN     22999      1267
# 41   4101   190035     3088      1.0      100      NaN     33541      1549
# 42   4102   175586     2971      1.0      100      NaN     38398      1615
# 43   4103   245230     3496      0.9      100      NaN     41854      1737
# 44   4104   114217     2406      1.3      100      NaN     19625      1188
# 45   4105   192302     3106      1.0      100      NaN     43106      1705
# 46   4106   150563     2756      1.1      100      NaN     30424      1452
# 47   4107   142681     2684      1.1      100      NaN     29960      1434
# 48   4108   112457     2388      1.3      100      NaN     16049      1093
# 49   4109   135259     2615      1.2      100      NaN     23422      1297
# 50   4110   167870     2907      1.1      100      NaN     33754      1531
# 51   4111   140173     2661      1.2      100      NaN     32611      1475
# 52   4112   218003     3302      0.9      100      NaN     53177      1869
# 53   4113   129660     2561      1.2      100      NaN     28519      1390
# 54   4114   103729     2294      1.3      100      NaN     25898      1299
#
#     PU16_00C  PU16_00P  ...  Pop_H00E.1  Pop_H00M.1  Pop_H00C.1  Pop_H00P.1  \
# 0        3.3      21.3  ...       40432        2498         3.8         100
# 1        2.7      24.4  ...       24744        2250         5.5         100
# 2        3.4      19.7  ...       27410        2269         5.0         100
# 3        3.2      20.6  ...       40361        2591         3.9         100
# 4        2.3      30.4  ...       81114        2925         2.2         100
# 5        2.5      28.6  ...       78690        2803         2.2         100
# 6        2.2      32.0  ...       83751        2830         2.1         100
# 7        2.3      30.9  ...       76263        2810         2.2         100
# 8        2.2      26.7  ...       97620        3280         2.0         100
# 9        2.4      28.6  ...       97089        2769         1.7         100
# 10       2.2      22.6  ...      165023        3292         1.2         100
# 11       3.3      19.1  ...       51168        2744         3.3         100
# 12       3.0      24.6  ...       18903        1975         6.4         100
# 13       2.9      24.5  ...       63431        2698         2.6         100
# 14       3.4      11.1  ...       13496        1775         8.0         100
# 15       3.5      11.7  ...       29827        2507         5.1         100
# 16       5.6       7.6  ...       19844        2035         6.2         100
# 17       5.2       7.5  ...       10335        1545         9.1         100
# 18       3.4      14.3  ...       47827        2916         3.7         100
# 19       5.2       8.5  ...        7317        1309        10.9         100
# 20       2.7      21.9  ...        9958        1523         9.3         100
# 21       3.0      21.0  ...       12610        1684         8.1         100
# 22       2.5      24.3  ...       29438        2449         5.1         100
# 23       2.6      25.6  ...       49113        2830         3.5         100
# 24       2.6      29.4  ...       78302        2526         2.0         100
# 25       2.6      28.7  ...       23457        2169         5.6         100
# 26       3.8      16.5  ...       22420        2115         5.7         100
# 27       3.8      17.3  ...       25814        2212         5.2         100
# 28       2.9      24.2  ...       10741        1560         8.8         100
# 29       2.4      32.8  ...       22671        2127         5.7         100
# 30       2.4      28.3  ...       56633        2920         3.1         100
# 31       2.4      23.4  ...       15169        1864         7.5         100
# 32       2.6      24.0  ...        8019        1373        10.4         100
# 33       3.0      23.8  ...        9289        1457         9.5         100
# 34       2.8      23.3  ...       65026        2909         2.7         100
# 35       3.6      16.9  ...       12853        1692         8.0         100
# 36       2.2      29.2  ...       17638        1977         6.8         100
# 37       2.4      25.2  ...       20354        2106         6.3         100
# 38       3.0      19.3  ...        9641        1499         9.4         100
# 39       2.9      17.9  ...       14120        1796         7.7         100
# 40       3.3      19.7  ...       18387        1963         6.5         100
# 41       2.8      17.6  ...       51963        3065         3.6         100
# 42       2.6      21.9  ...      104117        3247         1.9         100
# 43       2.5      17.1  ...       40480        2900         4.4         100
# 44       3.7      17.2  ...       10034        1509         9.1         100
# 45       2.4      22.4  ...       19657        2096         6.5         100
# 46       2.9      20.2  ...       25753        2305         5.4         100
# 47       2.9      21.0  ...       70029        2979         2.6         100
# 48       4.1      14.3  ...       12579        1667         8.1         100
# 49       3.4      17.3  ...       46045        2749         3.6         100
# 50       2.8      20.1  ...       46291        2888         3.8         100
# 51       2.7      23.3  ...       47437        2795         3.6         100
# 52       2.1      24.4  ...       28828        2495         5.3         100
# 53       3.0      22.0  ...       24347        2218         5.5         100
# 54       3.1      25.0  ...       17107        1885         6.7         100
#
#     Pop_H00Z.1  FB_H00E  FB_H00M  FB_H00C  FB_H00P  FB_H00Z
# 0          NaN    15382     1234      4.9     38.0      1.9
# 1          NaN     4095      678     10.1     16.5      2.3
# 2          NaN     3013      582     11.7     11.0      1.9
# 3          NaN     9939     1028      6.3     24.6      2.0
# 4          NaN    21829     1461      4.1     26.9      1.5
# 5          NaN    29646     1630      3.3     37.7      1.6
# 6          NaN    35512     1742      3.0     42.4      1.5
# 7          NaN    33027     1689      3.1     43.3      1.5
# 8          NaN    23009     1521      4.0     23.6      1.3
# 9          NaN    25930     1566      3.7     26.7      1.4
# 10         NaN   100226     2532      1.5     60.7      0.9
# 11         NaN    28524     1596      3.4     55.7      0.9
# 12         NaN     7394      893      7.3     39.1      2.4
# 13         NaN    15823     1259      4.8     24.9      1.7
# 14         NaN     5421      782      8.8     40.2      2.4
# 15         NaN    11879     1136      5.8     39.8      1.8
# 16         NaN     7463      901      7.3     37.6      2.4
# 17         NaN     3019      585     11.8     29.2      3.6
# 18         NaN    10679     1075      6.1     22.3      1.8
# 19         NaN     2495      532     13.0     34.1      3.9
# 20         NaN     2246      506     13.7     22.6      3.7
# 21         NaN     2695      553     12.5     21.4      3.3
# 22         NaN     7803      927      7.2     26.5      2.2
# 23         NaN    17110     1320      4.7     34.8      1.8
# 24         NaN    26910     1547      3.5     34.4      1.6
# 25         NaN     6642      852      7.8     28.3      2.5
# 26         NaN     5524      780      8.6     24.6      2.6
# 27         NaN     6747      856      7.7     26.1      2.4
# 28         NaN     4704      723      9.3     43.8      2.2
# 29         NaN     6530      844      7.9     28.8      2.6
# 30         NaN    20312     1420      4.3     35.9      1.7
# 31         NaN     4037      676     10.2     26.6      3.0
# 32         NaN     3929      665     10.3     49.0     11.8
# 33         NaN     5126      753      8.9     55.2     11.9
# 34         NaN    25677     1553      3.7     39.5      1.6
# 35         NaN     4268      690      9.8     33.2      3.1
# 36         NaN     8350      957      7.0     47.3      1.1
# 37         NaN    10143     1049      6.3     49.8      7.3
# 38         NaN     3553      634     10.8     36.9      3.2
# 39         NaN     5998      818      8.3     42.5      2.1
# 40         NaN     6577      847      7.8     35.8      2.6
# 41         NaN    29859     1706      3.5     57.5      4.7
# 42         NaN    72726     2220      1.9     69.9      3.0
# 43         NaN    23279     1561      4.1     57.5      5.6
# 44         NaN     4491      706      9.6     44.8      2.1
# 45         NaN     7231      897      7.5     36.8      2.3
# 46         NaN    12056     1133      5.7     46.8      1.3
# 47         NaN    48362     1923      2.4     69.1      4.0
# 48         NaN     6167      821      8.1     49.0      0.6
# 49         NaN    31371     1670      3.2     68.1      5.4
# 50         NaN    18429     1378      4.5     39.8      1.6
# 51         NaN    21381     1448      4.1     45.1      1.5
# 52         NaN    16079     1313      5.0     55.8      6.6
# 53         NaN     8982      983      6.7     36.9      2.2
# 54         NaN     6886      862      7.6     40.3      2.4
#
# [55 rows x 426 columns]

# %%
df_puma.columns = df_puma.columns.str.replace("Pop_00E" , "total_pop", regex=True)

# %%
new_df.head()
# Out:
#        Pop_00E  Pop_00M  Pop_00C  Pop_00P  Pop_00Z  PU16_00E  PU16_00M  \
# GeoID
# 3701    106386     2323      1.3      100      NaN     22622      1244
# 3702    139419     2654      1.2      100      NaN     34020      1495
# 3703    111738     2380      1.3      100      NaN     22050      1240
# 3704    121704     2482      1.2      100      NaN     25024      1314
# 3705    140777     2667      1.2      100      NaN     42829      1609
#
#        PU16_00C  PU16_00P  PU16_00Z  ...  Pop_H00E.1  Pop_H00M.1  Pop_H00C.1  \
# GeoID                                ...
# 3701        3.3      21.3       1.1  ...       40432        2498         3.8
# 3702        2.7      24.4       1.0  ...       24744        2250         5.5
# 3703        3.4      19.7       1.0  ...       27410        2269         5.0
# 3704        3.2      20.6       1.0  ...       40361        2591         3.9
# 3705        2.3      30.4       1.0  ...       81114        2925         2.2
#
#        Pop_H00P.1  Pop_H00Z.1  FB_H00E  FB_H00M  FB_H00C  FB_H00P  FB_H00Z
# GeoID
# 3701          100         NaN    15382     1234      4.9     38.0      1.9
# 3702          100         NaN     4095      678     10.1     16.5      2.3
# 3703          100         NaN     3013      582     11.7     11.0      1.9
# 3704          100         NaN     9939     1028      6.3     24.6      2.0
# 3705          100         NaN    21829     1461      4.1     26.9      1.5
#
# [5 rows x 425 columns]
